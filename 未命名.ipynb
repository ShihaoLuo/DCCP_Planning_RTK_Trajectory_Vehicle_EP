# %%
import requests
import socket

# %%
#get ep ip
ip_sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
ip_sock.bind(('0.0.0.0', 40926))
ip_str = ip_sock.recvfrom(1024)
print(ip_str)

# %%
url = "http://api.map.baidu.com/geoconv/v1/?coords=114.21892734521,29.575429778924&from=1\
    &to=6&ak=Oei9p1GZmXAtP4ynH3NE3j42uFz21ynt"
res = requests.get(url)
print(res.content)
# Out:
# b'{"status":0,"result":[{"x":12716247.50382771,"y":3428274.0907844568}]}'
